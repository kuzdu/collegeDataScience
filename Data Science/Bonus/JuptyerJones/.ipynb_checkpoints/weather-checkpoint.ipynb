# %%
import pandas as pd
import matplotlib.pyplot as plt

racesCreated = pd.read_csv("races.csv", sep=";")
racesCreated.dropna(how="all")
racesCreated.head()
# Out:
#    id race_created          race_driven  track_id  challenger  opponent  \
# 0   1   06.03.2012     06.03.2012 00:00        12           5         2
# 1   2   06.03.2012     06.03.2012 00:03        12           5         4
# 2   3   06.03.2012  0000-00-00 00:00:00         3          10         5
# 3   4   06.03.2012     06.03.2012 00:06        12           5         4
# 4   5   06.03.2012  0000-00-00 00:00:00        12           4         5
#
#    money fuel_consumption  winner    status  \
# 0     30             0.63       5  finished
# 1     30             0.63       4  finished
# 2     30             0.63       0  declined
# 3     30             0.63       5  finished
# 4     30             0.63       0  declined
#
#                                             forecast weather
# 0  a:4:{s:5:"sunny";i:10;s:5:"rainy";i:70;s:8:"th...   rainy
# 1  a:4:{s:5:"sunny";i:70;s:5:"rainy";i:15;s:8:"th...   sunny
# 2  a:4:{s:5:"sunny";i:70;s:5:"rainy";i:10;s:8:"th...     NaN
# ...
