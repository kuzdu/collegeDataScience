# %%
import pandas as pd
import matplotlib.pyplot as plt

challenger_opponent_data_frame = pd.read_csv("races.csv", sep=";", usecols=['challenger','opponent'])

# remove Nans
challenger_opponent_data_frame.dropna(how="all")
challenger_opponent_data_frame
# Out:
#         challenger  opponent
# 0                5         2
# 1                5         4
# 2               10         5
# 3                5         4
# 4                4         5
# 5                5        10
# 6                8         5
# 7                8         2
# 8               10         4
# 9                8        10
# 10               4         8
# 11               5         8
# 12               5         8
# 13               5         3
# 14               3         5
# 15               5         3
# 16               3         8
# 17               8        10
# 18               8         3
# 19               3         8
# 20               3         8
# 21               3        20
# 22               8         3
# 23               8        20
# 24               8         0
# 25               8        20
# 26              20         1
# 27              20         5
# 28              20        22
# 29              20         8
# ...            ...       ...
# ...

# %%
top_five_challenger=pd.value_counts(challenger_opponent_data_frame.challenger).to_frame().head()
top_five_challenger
# Out:
#       challenger
# 48         16962
# 2866        4898
# 32          4315
# 46          4205
# 5           3034

# %% [markdown]
# Spieler _48_ war _16962_ mal challenger
#
# Spieler _2866_ war _4898_ mal challenger
#
# Spieler _32_ war _4315_ mal challenger
#
# Spieler _46_ war _4205_ mal challenger
#
# Spieler _5_ war _3034_ mal challenger

# %%
top_five_opponents=pd.value_counts(challenger_opponent_data_frame.opponent).to_frame().head()
top_five_opponents
# Out:
#       opponent
# 0        15190
# 48        3732
# 2866      2616
# 32        1944
# 55        1587

# %%
Spieler _0_ war _15190_ mal opponent

Spieler _48_ war _3732_ mal opponent

Spieler _2866_ war _2616_ mal opponent

Spieler _32_ war _1944_ mal opponent

Spieler _55_ war _1587_ mal opponent

# %% [markdown]
# Wäre noch interessant: Wann hat Spieler 0 z.B: das letzte Mal gespielt? Und wann das erste Mal?
