# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import model_selection, datasets
from sklearn.linear_model import LogisticRegression

dataset = datasets.load_iris()

possbile_iris_flower = [4.8,2.5,5.3,2.4]

data_sepal_length = np.array([item[0] for item in iris["data"]]).reshape(-1,1) 

target = (dataset.target == 2).astype(np.int)

logistic = LogisticRegression()
logistic.fit(data_sepal_length,target)

X_new = np.linspace(0,15,1000).reshape(-1,1) 
Y_proba = logistic.predict_proba(X_new)
   

#plot grafic
plt.xlabel("Sepal Length", fontsize=14)
plt.ylabel("Probability", fontsize=14)
plt.plot(X_new,Y_proba[:,1],"g-",label="Iris-Virginica")
plt.plot(X_new,Y_proba[:,0],"b--",label="Not Iris-Virginca")
plt.legend(loc="upper right", fontsize=14)
plt.show()

#0 = not, 1 = yes
print(logistic.predict(possbile_iris_flower[0]))
# Out:
# [0]

# %%
dataset = datasets.load_iris()

data_sepal_width = np.array([item[1] for item in iris["data"]]).reshape(-1,1) 

target = (dataset.target == 2).astype(np.int)
  
logistic = LogisticRegression()
logistic.fit(data_sepal_width,target)

X_new = np.linspace(0,15,1000).reshape(-1,1)
Y_proba = logistic.predict_proba(X_new)
 
#plot grafic
plt.xlabel("Sepal Width", fontsize=14)
plt.ylabel("Probability", fontsize=14)
plt.plot(X_new,Y_proba[:,1],"g-",label="Iris-Virginica")
plt.plot(X_new,Y_proba[:,0],"b--",label="Not Iris-Virginca")
plt.legend(loc="upper left", fontsize=14)
plt.show()

#0 = not, 1 = yes
print(logistic.predict(possbile_iris_flower[1]))
# Out:
# [0]

# %%
dataset = datasets.load_iris()

possbile_iris_flower = [4.8,2.5,5.3,2.4]

data_pedal_length = np.array([item[2] for item in iris["data"]]).reshape(-1,1) 

target = (dataset.target == 2).astype(np.int)
  
logistic = LogisticRegression()
logistic.fit(data_pedal_length,target)

X_new = np.linspace(0,15,1000).reshape(-1,1) 
Y_proba = logistic.predict_proba(X_new)
 
#plot grafic
plt.xlabel("Pedal Length", fontsize=14)
plt.ylabel("Probability", fontsize=14)
plt.plot(X_new,Y_proba[:,1],"g-",label="Iris-Virginica")
plt.plot(X_new,Y_proba[:,0],"b--",label="Not Iris-Virginca")
plt.legend(loc="upper right", fontsize=14)
plt.show()

#0 = not, 1 = yes
print(logistic.predict(possbile_iris_flower[2]))
# Out:
# [1]

# %%
data_pedal_width = np.array([item[3] for item in iris["data"]]).reshape(-1,1) 

target = (dataset.target == 2).astype(np.int)
  
logistic = LogisticRegression()
logistic.fit(data_pedal_width,target)

X_new = np.linspace(0,15,1000).reshape(-1,1) 
Y_proba = logistic.predict_proba(X_new)
 
#plot grafic
plt.xlabel("Pedal Width", fontsize=14)
plt.ylabel("Probability", fontsize=14)
plt.plot(X_new,Y_proba[:,1],"g-",label="Iris-Virginica")
plt.plot(X_new,Y_proba[:,0],"b--",label="Not Iris-Virginca")
plt.legend(loc="upper right", fontsize=14)
plt.show()

#0 = not, 1 = yes
print(logistic.predict(possbile_iris_flower[3]))
# Out:
# [1]

# %%
"I don't think that the found flower is an iris an virginica because two times I receive 0 and just two times a 1."
# Out:
# "I don't think that the found flower is an iris an virginica because two times I receive 0 and just two times a 1."

# %%
"If you have a look to the grafics the possibilites that it is an iris flower seem to be ~0.2, ~0.33, ~0.6, ~0.8. So the possibilites aren't very high."
# Out:
# 'If you have a look to the grafics the possibilites that it is a iris flower seem to be ~0.2, ~0.1'
